# %% [markdown]
# # **File Prepping Dev**
#
# ### Justin Vinh | 2025.09.25
#
# This is the development notebook to develop modules to process files
# from OncDRS for use in LLM-related research

# %%
import pandas as pd
import config_path
